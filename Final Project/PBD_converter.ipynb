# %%
from pdbfixer import PDBFixer
from openmm.app import PDBFile

# %% [markdown]
# From PBDFixer Manual

# %%
fixer = PDBFixer(filename='8TBB TIM-3 Antibody.pdb1')
fixer.findMissingResidues()
fixer.findNonstandardResidues()
fixer.replaceNonstandardResidues()
fixer.removeHeterogens(True)
fixer.findMissingAtoms()
fixer.addMissingAtoms()
fixer.addMissingHydrogens(7.0)
fixer.addSolvent(fixer.topology.getUnitCellDimensions())
PDBFile.writeFile(fixer.topology, fixer.positions, open('TIM-3_prepared.pdb', 'w'))

# %% [markdown]
# Mine

# %%
fixer = PDBFixer(filename='8TBB TIM-3 Antibody.pdb1')
fixer.findMissingResidues()
fixer.findNonstandardResidues()
fixer.replaceNonstandardResidues()
fixer.removeHeterogens(True)
fixer.findMissingAtoms()
fixer.addMissingAtoms()
fixer.addMissingHydrogens(7.0)
PDBFile.writeFile(fixer.topology, fixer.positions, open('TIM-3_prepared_2.pdb', 'w'))

# %%
fixer = PDBFixer(filename='8TBB TIM-3 Antibody.pdb1')
fixer.findMissingResidues()
fixer.findMissingAtoms()
fixer.addMissingAtoms()
fixer.addMissingHydrogens(7.0)
PDBFile.writeFile(fixer.topology, fixer.positions, open('TIM-3_prepared_3.pdb', 'w'))

# %%
fixer = PDBFixer(filename='8TBB TIM-3 Antibody.pdb1')
PDBFile.writeFile(fixer.topology, fixer.positions, open('TIM-3_prepared_4.pdb', 'w'))
