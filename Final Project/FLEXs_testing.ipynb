# %% [markdown]
# # Trying out FLEXs

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

import flexs
# Out:
# The kernel failed to start as 'TypeAliasType' could not be imported from '/Users/nicksmits/miniforge3/envs/flexs-py310/lib/python3.10/site-packages/typing_extensions.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
